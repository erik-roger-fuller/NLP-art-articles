# %%
import numpy as np
import pandas as pd
#import pickle
from textblob import TextBlob
import matplotlib.pyplot as plt
import matplotlib.lines as ln
from matplotlib.dates import YearLocator, MonthLocator, DateFormatter, drange , date2num
import json
import os
import nltk
from nltk import RegexpTokenizer
#from collections import Counter
import re
from datetime import datetime
import time
#import string

# %%
global_path = '~/Desktop/Datasets/art/art_writing'
path = 'artnet_articles'
#path = 'artnet_articles'
#path = 'artnet_articles'
folderpath = os.path.expanduser(os.path.join(global_path, path))

filelist = os.listdir(folderpath)

# %%
data = {}
data = pd.DataFrame(data)

cleaned_titles = []
cleaned_paras = []
brought_in = 0

for file in filelist: #[:100]:
    filepath = os.path.join(folderpath, file)
    f = open(filepath) #, encoding='ascii', errors='ignore')
    try:
        j_import = json.load(f)
        j_import = j_import[0]
        #print(j_import)
        #title = j_import['title']
        try:
            para = j_import['para']
            para = para[0]
            tokenizer = RegexpTokenizer(r'\w+')
            tokens = tokenizer.tokenize(para)
            #print(tokens)
            count = len(tokens)
            if count > 1000 and brought_in < 1000:
                brought_in += 1
                para = para.replace("	", "").replace("Follow  on Facebook:", '').replace("\n", ' ')
                para = para.replace("\r" , " ")
                para = para.strip()
                #print(para)

                title = j_import['title']
                title = title.replace("	", "").replace("\n", ' ')
                title = title.replace("\r" , " ")
                title = title.strip()

                author = j_import['author']
                author = author.replace("	", "").replace("\n", ' ')
                author = author.replace("\r" , " ")
                author = author.strip()

                pubtime_i = j_import['pubtime']
                pubtime_i = pubtime_i[:19]
                #pubtime_i = pubtime_i.replace( "+00:00", "").replace("T" , " ")
                #pubtime_i = pubtime_i[:10]

                #pubyear = pubtime_i[:4]
                #pubmon = pubtime_i[6:7]
                #pubday = pubtime_i[-2:]
                #print(pubtime_i)
                pubtime = datetime(*time.strptime(pubtime_i, "%Y-%m-%dT%H:%M:%S")[:6])

                new_row = {"title" : title , "para" : para , "author": author ,
                           "pubtime" : pubtime }
                data = data.append(new_row, ignore_index=True)
                f.close()
            else:
                pass

        except KeyError:
            f.close()
            pass

    except json.decoder.JSONDecodeError:
        f.close()
        pass

#data = data.set_index('title')
data
# Out:
#                  author                                               para  \
# 0           Artnet News  Art Industry News is a daily digest of the mos...
# 1    Caroline Goldstein  In another installment of our series investiga...
# 2         Brian Boucher  As museum acquisitions grow, and amid a balloo...
# 3         Vivienne Chow  On June 30, the eve of the 23rd anniversary of...
# 4          Taylor Dafoe  A year ago, artist Allison Zuckerman was 26, f...
# ..                  ...                                                ...
# 995          Kate Brown  Lee Mingwei was lucky. At the urging of the Gr...
# 996     Kenny Schachter  When I began my career, art fairs were still i...
# 997          Karen Wong  The optics were spot-on last weekend for the o...
# 998     Kenny Schachter  Having just returned from Paris and the 44th e...
# 999          Kate Brown  As the Venice Biennale drew to a close last mo...
#
#                 pubtime                                              title
# 0   2019-03-20 13:16:19  Art Industry News: Obama Portraitist Kehinde W...
# 1   2019-11-08 17:18:05  See the Poetic, Heartbreaking Final Paintings ...
# 2   2016-08-12 15:21:58  From Auschwitz Drawings to Teddy Bears, ‘The K...
# 3   2020-07-16 12:59:43  Beijing Is Clamping Down on ‘Subversive’ Activ...
# 4   2017-12-05 14:14:32  Behind Artist Allison Zuckerman’s Rapid Rise F...
# ..                  ...                                                ...
# 995 2020-05-18 06:00:16  ‘Plexiglass Has Become a Symbol of Care’: How ...
# 996 2017-10-10 06:00:26  Sculduggery, Weak Bladders, and the Wrath of t...
# 997 2016-06-01 13:01:36  9 Reasons Venice Is Unmissable During the Arch...
# 998 2017-10-25 13:18:02  Kenny Schachter on Bad Behavior at FIAC and th...
# 999 2019-12-18 18:36:49  In the Wake of Devastating Floods, It’s High T...
#
# [1000 rows x 4 columns]

# %%
#polarity ananlysis of paras
pol = lambda x: TextBlob(x).sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity

data['polarity'] = data['para'].apply(pol)
data['subjectivity'] = data['para'].apply(sub)
data
# Out:
#                  author                                               para  \
# 0           Artnet News  Art Industry News is a daily digest of the mos...
# 1    Caroline Goldstein  In another installment of our series investiga...
# 2         Brian Boucher  As museum acquisitions grow, and amid a balloo...
# 3         Vivienne Chow  On June 30, the eve of the 23rd anniversary of...
# 4          Taylor Dafoe  A year ago, artist Allison Zuckerman was 26, f...
# ..                  ...                                                ...
# 995          Kate Brown  Lee Mingwei was lucky. At the urging of the Gr...
# 996     Kenny Schachter  When I began my career, art fairs were still i...
# 997          Karen Wong  The optics were spot-on last weekend for the o...
# 998     Kenny Schachter  Having just returned from Paris and the 44th e...
# 999          Kate Brown  As the Venice Biennale drew to a close last mo...
#
#                 pubtime                                              title  \
# 0   2019-03-20 13:16:19  Art Industry News: Obama Portraitist Kehinde W...
# 1   2019-11-08 17:18:05  See the Poetic, Heartbreaking Final Paintings ...
# 2   2016-08-12 15:21:58  From Auschwitz Drawings to Teddy Bears, ‘The K...
# 3   2020-07-16 12:59:43  Beijing Is Clamping Down on ‘Subversive’ Activ...
# 4   2017-12-05 14:14:32  Behind Artist Allison Zuckerman’s Rapid Rise F...
# ..                  ...                                                ...
# 995 2020-05-18 06:00:16  ‘Plexiglass Has Become a Symbol of Care’: How ...
# 996 2017-10-10 06:00:26  Sculduggery, Weak Bladders, and the Wrath of t...
# 997 2016-06-01 13:01:36  9 Reasons Venice Is Unmissable During the Arch...
# 998 2017-10-25 13:18:02  Kenny Schachter on Bad Behavior at FIAC and th...
# 999 2019-12-18 18:36:49  In the Wake of Devastating Floods, It’s High T...
#
#      polarity  subjectivity
# 0    0.054726      0.401017
# 1    0.031590      0.373545
# 2    0.105503      0.550281
# 3    0.125655      0.373245
# 4    0.142478      0.415025
# ..        ...           ...
# 995  0.136375      0.503566
# 996  0.123729      0.491374
# 997  0.095360      0.429797
# 998  0.122305      0.503587
# 999  0.081517      0.423649
#
# [1000 rows x 6 columns]

# %%
# Let's plot the results
plt.rcParams['figure.figsize'] = [15, 8]

for index, para in enumerate(data.index):
    x = data.polarity.loc[para]
    y = data.subjectivity.loc[para]
    #ln.Line2D(xdata=[0,0] , ydata =[0,1.0] , linewidth=1 , color="black")
    plt.scatter(x, y, color='red', s=3)
    
    #plt.text(x+.001, y+.001, data['author'][index], fontsize=5)
    plt.xlim(-.15, .3) 

    

  
plt.title('Sentiment Analysis', fontsize=20)
plt.xlabel('<-- Negative -------- Positive -->', fontsize=15)
plt.ylabel('<-- Factlike -------- Opinions -->', fontsize=15)

plt.show()

# %%
data.sort_values(by=['pubtime'], inplace=True )
data
# Out:
#                                    author  \
# 840                         Deanie Hoxter
# 321                     Katherine Markley
# 967                        Cyril Bourlier
# 297                         Jessica Zhang
# 406  Ronald D. Spencer and Judith Wallace
# ..                                    ...
# 828                           Artnet News
# 386                         Sarah Cascone
# 877                      Kimberly Bradley
# 280                           Katie White
# 422                            Noor Brara
#
#                                                   para             pubtime  \
# 840  By using art to reflect on personal history an... 2013-04-10 17:11:16
# 321  On February 6, Berthe Morisot ’s 1881 painting... 2013-04-29 19:46:09
# 967  Le Calin Catalan In 1907, he started business ... 2013-06-12 18:05:47
# 297  In September, artnet’s Jessica Zhang sat down ... 2013-11-25 05:03:46
# 406  This essay updates When Is It Too Late to Reco... 2014-02-12 17:23:02
# ..                                                 ...                 ...
# 828  Lisa Le Feuvre, the head of the Holt-Smithson ... 2021-02-02 06:30:12
# 386  Each week, we search for the most exciting and... 2021-02-09 15:17:51
# 877  O ut of the blue, in late 2020, I received a c... 2021-02-10 06:00:35
# 280  After the strange collective experience that w... 2021-02-10 06:30:19
# 422  Fine watchmaking and the arts have a long para... 2021-02-12 15:00:28
#
#                                                  title  polarity  subjectivity
# 840       Gallery Hopping on Thursdays: April 11, 2013  0.140540      0.376828
# 321       Once Again… Where Are All the Women Artists?  0.122439      0.343434
# 967                       An Introduction to Joan Miró  0.126468      0.469915
# 297  Interview with Philip Tinari, Director of the ...  0.123488      0.357337
# 406                     Art Law on Recovering Your Art  0.102392      0.437305
# ..                                                 ...       ...           ...
# 828  The Art World at Home: The Holt-Smithson Found...  0.230112      0.520191
# 386  Editors’ Picks: 13 Events for Your Art Calenda...  0.183924      0.435508
# 877  How Should the Art World Handle the Dark Legac...  0.065583      0.449199
# 280  What’s in Store for the Art World in 2021? We ...  0.199745      0.481525
# 422  ‘We’re Always Looking for Different Perspectiv...  0.222857      0.448090
#
# [1000 rows x 6 columns]

# %%
#time plot polarity
plt.rcParams['figure.figsize'] = [20, 10]

fig, ax = plt.subplots()
xs, ys , ysmooths = [] , [] , []

for index, para in enumerate(data.index):
    #pubdate_c = plt_dates.date2num(pubtime)
    xinput = data.pubtime.loc[para]
    x = date2num(xinput)
    xs.append(x)
    y = data.subjectivity.loc[para]
    ys.append(y)

for index, y in emumerate(ys.index):
    nexty =  ys[index+1]
    prevy = ys[index-1]
    ysmooth = (y + nexty + prevy) / 3
    ysmooths.append(ysmooth)
    
print(ys)   
#plt.text(x+.001, y+.001, data['author'][index], fontsize=5)
#plt.xlim(-.15, .3) 
x.arrange
sample = len(ys)
ax.set_title(f'{path} Sentiment Subjectivity Analysis \n with wordcount > {count}', fontsize=20)
ax.set_xlabel(f'Change over time.\n N={sample}', fontsize=15)
ax.set_ylabel('<-- Factlike \t\t Opinions -->', fontsize=15)

ax.tick_params(axis="x", rotation=30)
#set as years months x axis
ax.xaxis.set_major_locator(YearLocator())
#ax.xaxis.set_minor_locator(MonthLocator())
ax.xaxis.set_major_formatter(DateFormatter('%Y'))
#ax.xaxis.set_minor_formatter(DateFormatter('%m'))
ax.fmt_xdata = DateFormatter('%Y-%m')
fig.autofmt_xdate()

# round to nearest years.
#datemin = np.datetime64(data['pubtime'][0], 'Y')
#datemax = np.datetime64(data['pubtime'][-1], 'Y') + np.timedelta64(1, 'Y')
#ax.set_xlim(datemin, datemax)
ax.plot(xs, ysmooths)
#ax.scatter(xs, ys, color='green', s=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-164-2404d42ad8b8> in <module>
#      13     ys.append(y)
#      14
# ---> 15 for index, y in emumerate(ys.index):
#      16     nexty =  ys[index+1]
#      17     prevy = ys[index-1]
#
# NameError: name 'emumerate' is not defined

# %%
""" 


#ax.xaxis.set_major_locator(DayLocator())
#ax.xaxis.set_minor_locator(HourLocator(range(0, 25, 6)))
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m'))
ax.fmt_xdata = DateFormatter('%Y')
fig.autofmt_xdate()

ax = plt.subplots()
ax.plot('date')


            nonPunct = re.compile('.*[A-Za-z0-9].*')  # must contain a letter or digit
            filtered = [w for w in para if nonPunct.match(w)]
            counts = Counter(filtered)
            print (counts)
"""
